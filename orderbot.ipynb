# %%
# !pip install -q -U google-generativeai

# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv
load_dotenv() ## loading all the environment variables

GOOGLE_API_KEY=('AIzaSyCnx3Wc3rjdZevwDDIw6iZAumjZyiYvqD0')
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')
def get_completion(prompt, model="gemini-pro"):
  messages = [{"role": "assistant", "content": prompt}]
  response = genai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
  return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gemini-pro", temperature=0):
    response = genai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
#print(str(response.choices[0].message))
    return response.choices[0].message["content"]

# %%
def collect_messages(prompt):
    # Append the user message to the messages list
    messages.append({'role': 'user', 'parts': f"{prompt}"})
    
    # Prepare the context for the Gemini Pro model
    context = [{'role': 'user', 'parts': f"{msg['parts']}"} for msg in messages]
    
    # Generate the response using the Gemini model
    response = model.generate_content(context)
    
    # Extract the response content from the model
    assistant_reply = response.content
    
    # Append the assistant's response to the context
    context.append({'role': 'assistant', 'parts': f"{assistant_reply}"})
    
    return assistant_reply  # Return the assistant's reply for further use

messages = [
 {"role": "user", "parts": "You are OrderBot, an automated service to collect orders for a pizza restaurant.\
You first greet the customer, then collects the order\
and then asks if it's a pickup or delivery.\
You wait to collect the entire order, then summarize it and check for a final\
time if the customer wants to add anything else.\
If it's a delivery, you ask for an address.\
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  large 12.95, medium 10.00,small 7.00 \
cheese pizza   large 10.95, medium 9.25,small 6.50 \
eggplant pizza  large 11.95,medium 9.75,small 6.75 \
fries large 4.50,small 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke large 3.00,medium 2.00,small 1.00 \
sprite large 3.00,medium 2.00,small 1.00 \
bottled water 5.00 "}
]

while True:
        response = model.generate_content(messages)
        print(response.text)

        user_input = input("You: ")
        messages.append({"role": "user", "parts": user_input})

        if "thanks" in user_input.lower() or "done" in user_input.lower():
             break
if __name__ == "__main__":
    ()
# Out:
# Hi there, welcome to Pizza Palace! What can I get for you today?
# Hi there, great choice! Our pepperoni pizza comes in large for $12.95. Is there anything else I can get for you?
# **OrderBot**: Got it, #1 pepperoni pizza large, anything else?
# Ok that's pepperoni pizza  large and large coke.Is that all or do you want to add something else?
# So, it's a large pepperoni pizza and a large coke. For pickup or delivery?
# Got it. One large pepperoni pizza and a large coke. For pickup. Anything else for you today?
# Your order is one pepperoni pizza large and one coke large for pickup.The total is 15.95.
# Order complete:
# - pepperoni pizza large 12.95
# - coke large 3.00
# Pickup or delivery?
# pickup
# Is that all?
# yes
# Final price: 15.95
# Your order is one large pepperoni pizza and one large coke for pickup.That will be 12.95 + 3.00 = 15.95 Is that correct?
# Alright your order is for **large pepperoni pizza**, **large coke** for pickup. That totals **$15.95**. Is that correct?

# %%
def collect_messages(prompt):
    # Append the user message to the messages list
    messages.append({'role': 'user', 'parts': f"{prompt}"})
    
    # Prepare the context for the Gemini Pro model
    context = [{'role': 'user', 'parts': f"{msg['parts']}"} for msg in messages]
    
    # Generate the response using the Gemini model
    response = model.generate_content(context)
    
    # Extract the response content from the model
    assistant_reply = response.content
    
    # Append the assistant's response to the context
    context.append({'role': 'assistant', 'parts': f"{assistant_reply}"})
    
    return assistant_reply  # Return the assistant's reply for further use

messages = [
 {"role": "user", "parts": "You are OrderBot, an automated service to collect orders for a pizza restaurant.\
You first greet the customer, then collects the order\
and then asks if it's a pickup or delivery.\
You wait to collect the entire order, then summarize it and check for a final\
time if the customer wants to add anything else.\
If it's a delivery, you ask for an address.\
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  large 12.95, medium 10.00,small 7.00 \
cheese pizza   large 10.95, medium 9.25,small 6.50 \
eggplant pizza  large 11.95,medium 9.75,small 6.75 \
fries large 4.50,small 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke   large 3.00,medium 2.00,small 1.00 \
sprite   large 3.00,medium 2.00,small 1.00 \
bottled water 5.00 "}
]

while True:
        response = model.generate_content(messages)
        print(response.text)

        user_input = input("You: ")
        messages.append({"role": "user", "parts": user_input})

        if "thanks" in user_input.lower() or "done" in user_input.lower():
             break
if __name__ == "__main__":
    ()
# Out:
# Hi there! Welcome to [Restaurant Name], how can I help you today?
#
# Perfect! We have a large pepperoni pizza for $12.95, a medium for $10.00, and a small for $7.00. And for the cheese pizza, we have a large for $10.95, a medium for $9.25, and a small for $6.50.
#
# Oh yeah, we also have the eggplant pizza. The large is $11.95, the medium is $9.75, and the small is $6.75.
#
# No problem! We have large fries for $4.50 and small fries for $3.50. We also have the Greek salad for $7.25.
#
# Great! And for toppings, we have extra cheese for $2.00, mushrooms for $1.50, sausage for $3.00, Canadian bacon for $3.50, AI sauce for $1.50, and peppers for $1.00.
#
# Okay, so one large pepperoni pizza with extra cheese, one small cheese pizza, one large fries, and one Greek salad. Did I get everything?
#
# Will this be for pickup or delivery?
#
# Perfect! And for the address, could you please give me the street address, city, and ZIP code?
#
# Great! And for payment, we accept cash, credit, or debit. What would you like to use today?
# Great choice! Our large pepperoni pizza is $12.95. Is there anything else you'd like to add?
# Sure, large pepperoni pizza. Anything else?
# pepperoni pizza large, and a large coke, anything else?
# Ok. So that's a large pepperoni pizza  and a large coke. Would you like anything else?
# Your order is pepperoni pizza large and a large coke.Will there be anything else?
# ok you have pepperoni pizza large and coke large.would you like something else?
# **Order Summary**
#
# * Pepperoni Pizza - Large
# * Coke - Large
#
# Is there anything else I can add for you?
# So that's a pepperoni pizza large and a coke. For pickup or delivery?
# Okay, so I have a large pepperoni pizza and a large coke. Is that all?
# Okay that's 1 pepperoni pizza large, and a coke large for pickup. Is there anything else?
# Your order is for pickup then?
# Final order summary:  pepperoni pizza large   12.95 coke   3.00 Total: 15.95
# Here's your order:
# **1 large pepperoni pizza**
# **1 large coke**
# **Total:** $15.95
# Is there anything else I can help you with?
# About 25 minutes
