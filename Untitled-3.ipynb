# %%
import pandas as pd
# Load the Excel file
file_path = r"c:\Users\Admin\Desktop\pandas\rptempproj (4) (1).xlsx"

df = pd.read_excel(file_path)

data_dict = df.to_dict(orient="records")

print(df)
# Out:
#     Employee Project Mapping 01/01/2024 To 31/12/2024     Unnamed: 1  \
# 0                                       Employee Name  Employee Code
# 1                                            A Joseph         CC0210
# 2                                            A Joseph         CC0210
# 3                                            A Joseph         CC0210
# 4                                            A Joseph         CC0210
# ..                                                ...            ...
# 630                           Yuvaraja Chinnakaruppan         CC0305
# 631                           Yuvaraja Chinnakaruppan         CC0305
# 632                           Yuvaraja Chinnakaruppan         CC0305
# 633                                               NaN            NaN
# 634       Generated On: Monday, Sep 02, 2024 05:54 PM            NaN
#
#                       Unnamed: 2    Unnamed: 3                     Unnamed: 4  \
# ...

# %%
df = pd.read_excel(file_path, header=None)
        

df = df.iloc[1:-2]
        
df.columns = df.iloc[0] 
df = df[1:]


print(df)
# Out:
# 1              Employee Name Employee Code                 Project Name  \
# 2                   A Joseph        CC0210                Beach Runners
# 3                   A Joseph        CC0210  BeachRunners - ( Exhibit D)
# 4                   A Joseph        CC0210                        BENCH
# 5                   A Joseph        CC0210         CIDC Website Project
# 6                   A Joseph        CC0210                   MedPlex MD
# ..                       ...           ...                          ...
# 629  Yuvaraja Chinnakaruppan        CC0305            FIDO Security Dev
# 630  Yuvaraja Chinnakaruppan        CC0305            FIDO Security Dev
# 631  Yuvaraja Chinnakaruppan        CC0305            FIDO Security Dev
# 632  Yuvaraja Chinnakaruppan        CC0305            Sukraas - Phase 1
# 633  Yuvaraja Chinnakaruppan        CC0305                       URLane
#
# 1   Project Code                Project Manager            From Date  \
# ...

# %%
# Apply the formula to the 'Planned Loading' column in the first file
df['Planned Loading %'] = (df['Planned Loading %'] * 173) / 100


#df.to_excel('First DataFrame with updated 'Planned Loading3', index=False)

print("First DataFrame with updated 'Planned Loading':\n", df)
# Out:
# First DataFrame with updated 'Planned Loading':
#  1              Employee Name Employee Code                 Project Name  \
# 2                   A Joseph        CC0210                Beach Runners
# 3                   A Joseph        CC0210  BeachRunners - ( Exhibit D)
# 4                   A Joseph        CC0210                        BENCH
# 5                   A Joseph        CC0210         CIDC Website Project
# 6                   A Joseph        CC0210                   MedPlex MD
# ..                       ...           ...                          ...
# 629  Yuvaraja Chinnakaruppan        CC0305            FIDO Security Dev
# 630  Yuvaraja Chinnakaruppan        CC0305            FIDO Security Dev
# 631  Yuvaraja Chinnakaruppan        CC0305            FIDO Security Dev
# 632  Yuvaraja Chinnakaruppan        CC0305            Sukraas - Phase 1
# 633  Yuvaraja Chinnakaruppan        CC0305                       URLane
#
# ...
